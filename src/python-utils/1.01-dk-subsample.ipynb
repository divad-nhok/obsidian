# %%
import diagplots
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
parent_dir = '/Users/davidkohn/dev/obsidian/output/test_cr_synth_04/'
fname_readings = 'magReadings.csv'
fname_sensors = 'magSensors.csv'

# %%
fpath = os.path.join(parent_dir, fname_readings)
readings = pd.read_csv(fpath, header = None)

# %%
N = readings.shape[0]
halfN = int(N/2)
print(N, halfN)

# %%
samples_index_arr = np.random.randint(0, N, halfN)

# %%
samples_index_arr

# %%
new_readings = readings.loc[samples_index_arr, :]

# %%
new_readings[0].map('{:.1g}'.format)

# %%
new_readings.to_csv(
    os.path.join(parent_dir, 'magReadings2.csv'),
    index = False,
    header = False,
    float_format = '%2.18g'
)
