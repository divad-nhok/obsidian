# %% [markdown]
# # create new config from prospector prior samples
# - note that this exists in a script in the HPC obsidian directory

# %%
import diagplots
import os
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np

parent_dir = '/Users/davidkohn/dev/obsidian/output/synth_data/'
samples_fname = 'output.npz'
keys_of_interest = [
    'gravReadings',
    'magReadings'
]
sample_row_idx = 0
file_extension = '.csv'
mu_e = 0
sigma_e = 2
seed = 99

# %%
fpath = os.path.join(parent_dir, samples_fname)
samples = np.load(fpath)

np.random.seed(seed)
for key in keys_of_interest:
    sensor_samples = samples[key]
    fwd_model_obs = sensor_samples[sample_row_idx, :]
    e = np.random.normal(mu_e, sigma_e, fwd_model_obs.size)
    new_obs = fwd_model_obs + e
    fname = key + file_extension
    fpath = os.path.join(parent_dir, fname)
    np.savetxt(fpath, new_obs)

# %%
for key in samples.keys():
    vals = samples[key]
    n = vals.shape
    print(key, n)

# %% [markdown]
# # Other

# %% [markdown]
# # Try some plots

# %%
idx = 0
grav = samples['gravReadings'][idx, :]
mag = samples['magReadings'][idx, :]

# %%
plt.hist(grav - np.mean(grav))

# %%
plt.hist(mag - np.mean(mag))
