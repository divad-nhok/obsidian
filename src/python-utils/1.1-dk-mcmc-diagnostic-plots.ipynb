# %% [markdown]
# # mcmc output plots

# %%
import diagplots
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
parent_dir = '/Users/davidkohn/dev/obsidian/output/experiment_03_05_2018_14/'
samples_fname = 'output.npz'

selected_keys = [
    'layer0rockProperties',
    'layer0ctrlPoints',
    'layer1rockProperties',
    'layer1ctrlPoints',
    'layer2rockProperties',
    'layer2ctrlPoints',
    #'layer3rockProperties',
    #'layer3ctrlPoints',
]
plot_types = ['trace', 'hist']
save_dir = parent_dir

fig_width = 20
fig_height = 20
rows = 5
cols = 2
fontsize = 20

# %%
fpath = os.path.join(parent_dir, samples_fname)
samples = np.load(fpath)

# %%
for key in samples.keys():
    vals = samples[key]
    n = vals.shape
    print(key, n)

# %%
# trace plots and histograms
for key in selected_keys:
    for plot_type in plot_types:
        diagplots.parameters_plot(
            samples, 
            key,
            rows, cols,
            fig_width, fig_height,
            plot_type = plot_type,
            save_dir = save_dir
        )

# contour plots
diagplots.main_contours(
    data_dir = parent_dir,
    save_dir = parent_dir
)

# %%
diagplots.main_boundarymovie(parent_dir)

# %%
layers = 3
layer_labels = ['layer0rockProperties', 'layer1rockProperties', 'layer2rockProperties']
i = 0
layer_pars = np.array([samples[ll][i] for ll in layer_labels]).reshape(layers,5,5)

# %%
print(samples[layer_labels[0]].shape)
print(samples[layer_labels[1]].shape)
print(samples[layer_labels[2]].shape)
new_arr = np.array([samples[layer_labels[0]], samples[layer_labels[1]], samples[layer_labels[2]]])
print(new_arr.shape)

# %%
samples[layer_labels[0]].mean(axis = 1)

# %% [markdown]
# # Testing

# %%
params = samples['layer0rockProperties']
print(params.shape)
idx = 1
param = params[:, idx]
plt.hist(param)

# %%
thetas = samples['thetas']
print(thetas.shape)
theta_0 = thetas[:, 0]
plt.hist(theta_0)
theta_1 = thetas[:, 0]
plt.hist(theta_1)

# %%
ll = samples['likelihoods']
print(ll.shape)
ll_0 = ll[:, 0]
ll_1 = ll[:, 1]
ll_sum = ll_0 + ll_1
print(ll_sum.shape)
ll_sum = ll_sum.reshape(-1, 1)
print(ll_sum.shape)

# %%
plt.plot(theta_0, ll_0, 'o')

# %%
plt.plot(theta_1, ll_1, 'o')

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random


fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(theta_0, theta_1, ll_sum)
plt.show()

# %% [markdown]
# - need 3D grid of theta1 and theta2 points that I'm plotting over
# - need value of theta1 at each point in the grid
# - need value of theta2 at each point in the grid
# - need value of z at each point in the grid

# %%
x = np.linspace(-2, 2, 60)
y = np.linspace(-2, 2, 60)
X, Y = np.meshgrid(x, y)
Z = P(X, Y)
#X = X * 0
#Y = Y * 0
#Z = Z * 0

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.mlab as mlab
import numpy as np

def P(X, Y):
    return mlab.bivariate_normal(X, Y, 1.0, 1.0, 0.0, 0.0)      

fig = plt.figure()
ax = fig.gca(projection = '3d')
jet = plt.get_cmap('jet')


surf = ax.plot_surface(X, Y, Z, rstride = 1, cstride = 1, cmap = jet, linewidth = 0)
ax.set_zlim3d(0, Z.max())

plt.show()

# %%
surf = ax.plot_surface(X, Y, Z, rstride = 1, cstride = 1, cmap = jet, linewidth = 0)
ax.set_zlim3d(0, Z.max())

plt.show()

# %%
Y

# %%
X

# %%
Z[:,:] = Z[1, :]

# %%
Z
